# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %% [markdown]
# ## Loading dataset

# %%
data=pd.read_csv(r"C:\Users\VivekSharma\Downloads\Admission_Predict.csv")
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Chance of Admit
# 0             1        337          118                  4  4.5   4.5  9.65         1              0.92
# 1             2        324          107                  4  4.0   4.5  8.87         1              0.76
# 2             3        316          104                  3  3.0   3.5  8.00         1              0.72
# 3             4        322          110                  3  3.5   2.5  8.67         1              0.80
# 4             5        314          103                  2  2.0   3.0  8.21         0              0.65
# ..          ...        ...          ...                ...  ...   ...   ...       ...               ...
# 395         396        324          110                  3  3.5   3.5  9.04         1              0.82
# 396         397        325          107                  3  3.0   3.5  9.11         1              0.84
# 397         398        330          116                  4  5.0   4.5  9.45         1              0.91
# 398         399        312          103                  3  3.5   4.0  8.78         0              0.67
# 399         400        333          117                  4  5.0   4.0  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
data.drop('Serial No.',axis=1,inplace=True)

# %% [markdown]
# ## Train Test Split

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
X=data.drop('Chance of Admit ',axis=1)
y=data['Chance of Admit ']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2)

# %%
xtrain.shape,ytrain.shape
# Out:
# ((320, 7), (320,))

# %%
ss=StandardScaler()
for i in xtrain.columns:
    xtrain.loc[:,i]=ss.fit_transform(pd.DataFrame(xtrain.loc[:,i]))
    xtest.loc[:,i]=ss.transform(pd.DataFrame(xtest.loc[:,i]))

# %% [markdown]
# ## Deep Learning model

# %%
model=Sequential()
model.add(Dense(units=7,activation='relu'))
model.add(Dense(units=17,activation='relu'))
model.add(Dense(units=1,activation='linear'))

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
history=model.fit(xtrain,ytrain,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4269 - val_loss: 0.2348
# Epoch 2/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3067 - val_loss: 0.1666
# Epoch 3/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2426 - val_loss: 0.1374
# Epoch 4/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2037 - val_loss: 0.1224
# Epoch 5/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1770 - val_loss: 0.1108
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1553 - val_loss: 0.1003
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1359 - val_loss: 0.0908
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1208 - val_loss: 0.0828
# Epoch 9/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1086 - val_loss: 0.0762
# Epoch 10/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0982 - val_loss: 0.0707
# Epoch 11/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0895 - val_loss: 0.0659
# Epoch 12/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0823 - val_loss: 0.0617
# Epoch 13/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0761 - val_loss: 0.0582
# Epoch 14/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0706 - val_loss: 0.0543
# Epoch 15/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0653 - val_loss: 0.0510
# Epoch 16/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0605 - val_loss: 0.0479
# Epoch 17/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0560 - val_loss: 0.0450
# Epoch 18/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0518 - val_loss: 0.0424
# Epoch 19/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0479 - val_loss: 0.0396
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0443 - val_loss: 0.0373
# Epoch 21/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0347
# Epoch 22/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0371 - val_loss: 0.0322
# Epoch 23/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0340 - val_loss: 0.0301
# Epoch 24/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0312 - val_loss: 0.0281
# Epoch 25/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0286 - val_loss: 0.0265
# Epoch 26/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0262 - val_loss: 0.0249
# Epoch 27/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0242 - val_loss: 0.0232
# Epoch 28/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0221
# Epoch 29/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0204 - val_loss: 0.0209
# Epoch 30/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0200
# Epoch 31/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0176 - val_loss: 0.0190
# Epoch 32/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0164 - val_loss: 0.0180
# Epoch 33/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0171
# Epoch 34/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0162
# Epoch 35/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0131 - val_loss: 0.0155
# Epoch 36/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0146
# Epoch 37/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0137
# Epoch 38/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0132
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0124
# Epoch 40/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0119
# Epoch 41/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 0.0116
# Epoch 42/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0114
# Epoch 43/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0109
# Epoch 44/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0107
# Epoch 45/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 46/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0100
# Epoch 47/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 48/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0097
# Epoch 49/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0093
# Epoch 50/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0094
# Epoch 51/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 52/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0092
# Epoch 53/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0088
# Epoch 54/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0090
# Epoch 55/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0089
# Epoch 56/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0088
# Epoch 57/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0086
# Epoch 58/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0085
# Epoch 59/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0085
# Epoch 60/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0085
# Epoch 61/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0084
# Epoch 62/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0083
# Epoch 63/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0083
# Epoch 64/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0083
# Epoch 65/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0081
# Epoch 66/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0080
# Epoch 67/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0081
# Epoch 68/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0080
# Epoch 69/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0079
# Epoch 70/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0080
# Epoch 71/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0078
# Epoch 72/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0078
# Epoch 73/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 74/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0076
# Epoch 75/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0077
# Epoch 76/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 77/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 78/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0079
# Epoch 79/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0075
# Epoch 80/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0075
# Epoch 81/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0076
# Epoch 82/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0074
# Epoch 83/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 84/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 85/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0074
# Epoch 86/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0074
# Epoch 87/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 88/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 89/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 90/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 91/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0073
# Epoch 92/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 93/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 94/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0072
# Epoch 95/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 96/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0072
# Epoch 97/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0074
# Epoch 98/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0072
# Epoch 99/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0071
# Epoch 100/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0072

# %%
pred=model.predict(xtest)
r2_score(ytest,pred)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 0.7801393180303754
